# %%
import pandas as pd

df = pd.read_csv('../data/industrial_wastewater.csv')

df.head()
# Out:
#    source_id   source_name source_type iso3_country sector  \
# 0    4416905  Unknown name       steel          ALB  waste
# 1    4416905  Unknown name       steel          ALB  waste
# 2    4416905  Unknown name       steel          ALB  waste
# 3    4416905  Unknown name       steel          ALB  waste
# 4    4416905  Unknown name       steel          ALB  waste
#
#                                        subsector           start_time  \
# 0  industrial-wastewater-treatment-and-discharge  2021-01-01 00:00:00
# 1  industrial-wastewater-treatment-and-discharge  2021-02-01 00:00:00
# 2  industrial-wastewater-treatment-and-discharge  2021-03-01 00:00:00
# 3  industrial-wastewater-treatment-and-discharge  2021-04-01 00:00:00
# 4  industrial-wastewater-treatment-and-discharge  2021-05-01 00:00:00
#
#               end_time        lat        lon  ...  other7 other7_def  other8  \
# 0  2021-01-31 00:00:00  41.094611  20.026117  ...     NaN        NaN     NaN
# 1  2021-02-28 00:00:00  41.094611  20.026117  ...     NaN        NaN     NaN
# 2  2021-03-31 00:00:00  41.094611  20.026117  ...     NaN        NaN     NaN
# 3  2021-04-30 00:00:00  41.094611  20.026117  ...     NaN        NaN     NaN
# 4  2021-05-31 00:00:00  41.094611  20.026117  ...     NaN        NaN     NaN
#
#   other8_def  other9 other9_def  other10 other10_def         created_date  \
# 0        NaN     NaN        NaN      NaN         NaN  2024-09-20 00:00:00
# 1        NaN     NaN        NaN      NaN         NaN  2024-09-20 00:00:00
# 2        NaN     NaN        NaN      NaN         NaN  2024-09-20 00:00:00
# 3        NaN     NaN        NaN      NaN         NaN  2024-09-20 00:00:00
# 4        NaN     NaN        NaN      NaN         NaN  2024-09-20 00:00:00
#
#                 modified_date
# 0  2026-04-10 05:02:16.862423
# 1  2026-04-10 05:02:16.862423
# 2  2026-04-10 05:02:16.862423
# 3  2026-04-10 05:02:16.862423
# 4  2026-04-10 05:02:16.862423
#
# [5 rows x 43 columns]

# %%
df.shape
# Out:
# (79112, 43)

# %%
df.columns
# Out:
# Index(['source_id', 'source_name', 'source_type', 'iso3_country', 'sector',
#        'subsector', 'start_time', 'end_time', 'lat', 'lon', 'geometry_ref',
#        'gas', 'emissions_quantity', 'temporal_granularity', 'activity',
#        'activity_units', 'emissions_factor', 'emissions_factor_units',
#        'capacity', 'capacity_units', 'capacity_factor', 'other1', 'other1_def',
#        'other2', 'other2_def', 'other3', 'other3_def', 'other4', 'other4_def',
#        'other5', 'other5_def', 'other6', 'other6_def', 'other7', 'other7_def',
#        'other8', 'other8_def', 'other9', 'other9_def', 'other10',
#        'other10_def', 'created_date', 'modified_date'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 79112 entries, 0 to 79111
# Data columns (total 43 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   source_id               79112 non-null  int64
#  1   source_name             79112 non-null  str
#  2   source_type             79112 non-null  str
#  3   iso3_country            79112 non-null  str
#  4   sector                  79112 non-null  str
#  5   subsector               79112 non-null  str
#  6   start_time              79112 non-null  str
#  7   end_time                79112 non-null  str
#  8   lat                     79112 non-null  float64
#  9   lon                     79112 non-null  float64
#  10  geometry_ref            0 non-null      float64
#  11  gas                     79112 non-null  str
#  12  emissions_quantity      79112 non-null  int64
#  13  temporal_granularity    79112 non-null  str
#  14  activity                79112 non-null  float64
#  15  activity_units          79112 non-null  str
#  16  emissions_factor        79112 non-null  int64
#  17  emissions_factor_units  79112 non-null  str
#  18  capacity                79112 non-null  float64
#  19  capacity_units          79112 non-null  str
#  20  capacity_factor         79112 non-null  int64
#  21  other1                  0 non-null      float64
#  22  other1_def              0 non-null      float64
#  23  other2                  0 non-null      float64
#  24  other2_def              0 non-null      float64
#  25  other3                  0 non-null      float64
#  26  other3_def              0 non-null      float64
#  27  other4                  0 non-null      float64
#  28  other4_def              0 non-null      float64
#  29  other5                  0 non-null      float64
#  30  other5_def              0 non-null      float64
#  31  other6                  0 non-null      float64
#  32  other6_def              0 non-null      float64
#  33  other7                  0 non-null      float64
#  34  other7_def              0 non-null      float64
#  35  other8                  0 non-null      float64
#  36  other8_def              0 non-null      float64
#  37  other9                  0 non-null      float64
#  38  other9_def              0 non-null      float64
#  39  other10                 0 non-null      float64
#  40  other10_def             0 non-null      float64
#  41  created_date            79112 non-null  str
#  42  modified_date           79112 non-null  str
# dtypes: float64(25), int64(4), str(14)
# memory usage: 43.5 MB

# %%
df.isnull().sum()
# Out:
# source_id                     0
# source_name                   0
# source_type                   0
# iso3_country                  0
# sector                        0
# subsector                     0
# start_time                    0
# end_time                      0
# lat                           0
# lon                           0
# geometry_ref              79112
# gas                           0
# emissions_quantity            0
# temporal_granularity          0
# activity                      0
# activity_units                0
# emissions_factor              0
# emissions_factor_units        0
# capacity                      0
# capacity_units                0
# capacity_factor               0
# other1                    79112
# other1_def                79112
# other2                    79112
# other2_def                79112
# other3                    79112
# other3_def                79112
# other4                    79112
# other4_def                79112
# other5                    79112
# other5_def                79112
# other6                    79112
# other6_def                79112
# other7                    79112
# other7_def                79112
# other8                    79112
# other8_def                79112
# other9                    79112
# other9_def                79112
# other10                   79112
# other10_def               79112
# created_date                  0
# modified_date                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
empty_cols = [
    'geometry_ref',
    'other1', 'other1_def',
    'other2', 'other2_def',
    'other3', 'other3_def',
    'other4', 'other4_def',
    'other5', 'other5_def',
    'other6', 'other6_def',
    'other7', 'other7_def',
    'other8', 'other8_def',
    'other9', 'other9_def',
    'other10', 'other10_def'
]

df = df.drop(columns=empty_cols)

# %%
df.shape
# Out:
# (79112, 22)

# %%
df['start_time'] = pd.to_datetime(df['start_time'])

df['end_time'] = pd.to_datetime(df['end_time'])

df['created_date'] = pd.to_datetime(df['created_date'])

df['modified_date'] = pd.to_datetime(df['modified_date'])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 79112 entries, 0 to 79111
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   source_id               79112 non-null  int64
#  1   source_name             79112 non-null  str
#  2   source_type             79112 non-null  str
#  3   iso3_country            79112 non-null  str
#  4   sector                  79112 non-null  str
#  5   subsector               79112 non-null  str
#  6   start_time              79112 non-null  datetime64[us]
#  7   end_time                79112 non-null  datetime64[us]
#  8   lat                     79112 non-null  float64
#  9   lon                     79112 non-null  float64
#  10  gas                     79112 non-null  str
#  11  emissions_quantity      79112 non-null  int64
#  12  temporal_granularity    79112 non-null  str
#  13  activity                79112 non-null  float64
#  14  activity_units          79112 non-null  str
#  15  emissions_factor        79112 non-null  int64
#  16  emissions_factor_units  79112 non-null  str
#  17  capacity                79112 non-null  float64
#  18  capacity_units          79112 non-null  str
#  19  capacity_factor         79112 non-null  int64
#  20  created_date            79112 non-null  datetime64[us]
#  21  modified_date           79112 non-null  datetime64[us]
# dtypes: datetime64[us](4), float64(4), int64(4), str(10)
# memory usage: 24.5 MB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df.to_csv('../data/cleaned_wastewater.csv', index=False)

# %%
import os

os.listdir('../data')
# Out:
# ['cleaned_wastewater.csv', 'industrial_wastewater.csv']
